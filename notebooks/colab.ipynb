# %%
#!rm -rf ./results
# !export PYTHONNOUSERSITE=True
#!nequip-train nequip/configs/example.yaml
#!python /home/sire/phd/srz228573/nequip/nequip/nequip/scripts/train.py /home/sire/phd/srz228573/nequip/nequip/configs/example.yaml

# %%
# !nequip-train /home/sire/phd/srz228573/allegro/configs/example.yaml
# Out:
# * Initialize Output
#   ...generate file name /home/sire/phd/srz228573/benchmarking_datasets/allegro_data/aspirin/example/log
#   ...open log file /home/sire/phd/srz228573/benchmarking_datasets/allegro_data/aspirin/example/log
#   ...generate file name /home/sire/phd/srz228573/benchmarking_datasets/allegro_data/aspirin/example/metrics_epoch.csv
#   ...open log file /home/sire/phd/srz228573/benchmarking_datasets/allegro_data/aspirin/example/metrics_epoch.csv
#   ...generate file name /home/sire/phd/srz228573/benchmarking_datasets/allegro_data/aspirin/example/metrics_initialization.csv
#   ...open log file /home/sire/phd/srz228573/benchmarking_datasets/allegro_data/aspirin/example/metrics_initialization.csv
#   ...generate file name /home/sire/phd/srz228573/benchmarking_datasets/allegro_data/aspirin/example/metrics_batch_train.csv
#   ...open log file /home/sire/phd/srz228573/benchmarking_datasets/allegro_data/aspirin/example/metrics_batch_train.csv
# ...
